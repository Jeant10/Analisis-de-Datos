# %% [markdown]
# ## Vizualización

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randint(100, size=(20,4)), columns=["a","b","c","d"])
df
# Out:
#      a   b   c   d
# 0   71  12  12  53
# 1    8  25  70  71
# 2   74  93  36  89
# 3   13  15   7  33
# 4   90  68  48  14
# 5   32  21  49  87
# 6    4  67  16  61
# 7   96  69   3  89
# 8   28  91  24  25
# 9   26  41  83  28
# 10  64  51  46  70
# 11  66  45   5  10
# 12  76  96  55  43
# 13   2  32   1  31
# 14  20  27  35  53
# 15  83  58  59  80
# 16  32  36  16  99
# 17  23  85   0  59
# 18  76  66  87  50
# 19  40  95  69  45

# %%
df["a"].hist() 
# Histogramas
# Out:
# <AxesSubplot:>

# %%
df.plot.bar()
# Representacion de datos categoricos
# Out:
# <AxesSubplot:>

# %%
df.plot.bar(stacked=True)
# Representacion de datos categoricos
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x="a", y="b") 
# Gráficos de dispersión
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df.plot.scatter(x="a", y="b", c="c",cmap="coolwarm")
# Gráficos de dispersión en base a escala de color
# Out:
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\plotting\_matplotlib\tools.py:400: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df.plot.box()
# Diagrama de caja
# Out:
# <AxesSubplot:>

# %%
df.plot.kde()
# Diagrama de densidad
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Mathplolib

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (3.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: numpy>=1.16 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib) (1.20.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib) (8.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: six in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from cycler>=0.10->matplotlib) (1.15.0)

# %%
x = np.linspace(2,9,10)
y = x**2

# %%
plt.plot(x,y,"blue", linewidth=10, alpha=0.3)
plt.title('Ejemplo de gráficos', size=14)
plt.xlabel("Eje de la X")
plt.ylabel("Eje de la Y")
# Out:
# Text(0, 0.5, 'Eje de la Y')

# %%
figura, graficos= plt.subplots(nrows=2, ncols=2, figsize = (10, 5))
figura.suptitle('Ejemplo de gráficos', size=14)

graficos[0][0].plot(x,y,"blue", linewidth=10, alpha=0.3)
graficos[0][1].plot(x,y,"red", linestyle="-.") 
graficos[1][0].plot(x,y,"black", marker="s", markersize=5) 
graficos[1][1].plot(x,y,"green")

graficos[0][0].set_title("Azul")
graficos[0][1].set_title("Rojo")
graficos[1][0].set_title("Negro")
graficos[1][1].set_title("Verde")
# Out:
# Text(0.5, 1.0, 'Verde')

# %%
import matplotlib.pyplot as plt
import numpy as np

figure = plt.figure(figsize = (10, 5))

colores = ["blue","green","red","cyan","magenta","yellow","purple"]

for i in range(1,5): #numero de graficas 4
    x = np.linspace(2,9,10)
    y = x**2
    figure.tight_layout()#defino el acomodo de la graficas
    ax = plt.subplot(2,2,i) # acomodo de 2 filas 2 columnas
    ax.plot(x,y,color=colores[i])# grafico ax   
    ax.set_title("Gráfica " + str(i)) 
    ax.set_xlabel("Eje de las X")
    ax.set_ylabel("Eje de las Y")

# %% [markdown]
# ## Ejemplo con Database en linea

# %%
# !pip install seaborn
import seaborn as sns
propinas = sns.load_dataset("tips")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
# Requirement already satisfied: numpy>=1.15 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from seaborn) (1.20.1)
# Requirement already satisfied: pandas>=0.23 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from seaborn) (1.2.3)
# Requirement already satisfied: scipy>=1.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from seaborn) (1.6.2)
# Requirement already satisfied: matplotlib>=2.2 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from seaborn) (3.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from matplotlib>=2.2->seaborn) (8.3.2)
# Requirement already satisfied: six in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in c:\program files\arcgis\pro\bin\python\envs\arcgispro-py3\lib\site-packages\pytz-2020.1-py3.7.egg (from pandas>=0.23->seaborn) (2020.1)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.11.2

# %%
propinas
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lmplot(data=propinas,x="total_bill", y="tip")

# %%
sns.lmplot(data=propinas,x="total_bill", y="tip", hue="sex")

# %%
sns.lmplot(data=propinas,x="total_bill", y="tip", hue="sex", markers=["s","v"], scatter_kws={"s":90})

# %%
sns.lmplot(data=propinas,x="total_bill", y="tip", hue="day")

# %%
sns.lmplot(data=propinas,x="total_bill", y="tip", col="day")

# %%
sns.lmplot(data=propinas,x="total_bill", y="tip", col="day",hue="sex")

# %%
colores=["purple","yellow"]
sns.countplot(data=propinas,x="sex", palette= colores)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>
